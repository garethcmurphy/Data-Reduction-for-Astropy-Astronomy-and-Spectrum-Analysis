# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
cd py4ast/core
ls
# Out:
#   File "<ipython-input-2-fbda1a8be5ac>", line 1
#     cd py4ast/core
#             ^
# SyntaxError: invalid syntax

# %%
cd py4ast
# Out:
# /Users/gmurphy/datareduction/py4ast

# %%
cd core
# Out:
# /Users/gmurphy/datareduction/py4ast/core

# %%
from astropy.io import fits
hdus = fits.open('3c120_stis.fits.gz')
hdus
# Out:
# [<astropy.io.fits.hdu.image.PrimaryHDU at 0x111d8aac8>,
#  <astropy.io.fits.hdu.image.ImageHDU at 0x111d9fdd8>,
#  <astropy.io.fits.hdu.image.ImageHDU at 0x111da2e80>,
#  <astropy.io.fits.hdu.image.ImageHDU at 0x111dabfd0>]

# %%
hdus?

# %%
primary = hdus[0].data  # Primary (NULL) header data unit
img = hdus[1].data      # Intensity data
err = hdus[2].data      # Error per pixel
dq = hdus[3].data       # Data quality per pixel

# %%
plt.imshow(img)

# %%
plt.clf()
plt.imshow(img, origin = 'lower')

# %%
plt.imshow(img, origin = 'lower')

# %%
# %matplotlib inline

# %%
plt.imshow(img, origin = 'lower')

# %%
plt.clf()
plt.imshow(img, origin = 'lower', vmin = -10, vmax = 65)
plt.colorbar()

# %%
img?
